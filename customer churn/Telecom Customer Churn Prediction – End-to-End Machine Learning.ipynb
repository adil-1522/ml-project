# %% [raw]
# ## Business Objective
#
# Customer churn is a critical problem in the telecom industry.
# The objective of this project is to build a machine learning model that predicts
# whether a customer will churn, and to identify the key drivers behind churn
# so that proactive retention strategies can be designed.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\ADIL KHAN\ml-project\customer churn\data\telecom.csv")

# %%
print("Dataset Shape:", df.shape)
df.head()
# Out:
# Dataset Shape: (3333, 11)
#    Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  CustServCalls  \
# 0      0           128                1         1        2.7              1
# 1      0           107                1         1        3.7              1
# 2      0           137                1         0        0.0              0
# 3      0            84                0         0        0.0              2
# 4      0            75                0         0        0.0              3
#
#    DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0    265.1       110           89.0        9.87      10.0
# 1    161.6       123           82.0        9.78      13.7
# 2    243.4       114           52.0        6.06      12.2
# 3    299.4        71           57.0        3.10       6.6
# 4    166.7       113           41.0        7.42      10.1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Churn            3333 non-null   int64
#  1   AccountWeeks     3333 non-null   int64
#  2   ContractRenewal  3333 non-null   int64
#  3   DataPlan         3333 non-null   int64
#  4   DataUsage        3333 non-null   float64
#  5   CustServCalls    3333 non-null   int64
#  6   DayMins          3333 non-null   float64
#  7   DayCalls         3333 non-null   int64
#  8   MonthlyCharge    3333 non-null   float64
#  9   OverageFee       3333 non-null   float64
#  10  RoamMins         3333 non-null   float64
# dtypes: float64(5), int64(6)
# memory usage: 286.6 KB

# %%
df.describe()
# Out:
#              Churn  AccountWeeks  ContractRenewal     DataPlan    DataUsage  \
# count  3333.000000   3333.000000      3333.000000  3333.000000  3333.000000
# mean      0.144914    101.064806         0.903090     0.276628     0.816475
# std       0.352067     39.822106         0.295879     0.447398     1.272668
# min       0.000000      1.000000         0.000000     0.000000     0.000000
# 25%       0.000000     74.000000         1.000000     0.000000     0.000000
# 50%       0.000000    101.000000         1.000000     0.000000     0.000000
# 75%       0.000000    127.000000         1.000000     1.000000     1.780000
# max       1.000000    243.000000         1.000000     1.000000     5.400000
#
#        CustServCalls      DayMins     DayCalls  MonthlyCharge   OverageFee  \
# count    3333.000000  3333.000000  3333.000000    3333.000000  3333.000000
# mean        1.562856   179.775098   100.435644      56.305161    10.051488
# ...

# %%
churn_counts = df['Churn'].value_counts()

# %%
plt.figure()
churn_counts.plot(kind='bar')
plt.xlabel("Churn")
plt.ylabel("Count")
plt.title("Churn Distribution")
plt.show()

# %%
churn_counts / len(df)
# Out:
# Churn
# 0    0.855086
# 1    0.144914
# Name: count, dtype: float64

# %%
plt.figure()
df.boxplot(column='CustServCalls', by='Churn')
plt.title("Customer Service Calls vs Churn")
plt.suptitle("")
plt.xlabel("Churn")
plt.ylabel("Customer Service Calls")
plt.show()
#the median is high for the churn customers i.e more the customer calls more likely the customer will churn

# %%
pd.crosstab(df['ContractRenewal'], df['Churn'], normalize='index')
#here i understood that customers without contract renewal are more likely to churn
# Out:
# Churn                   0         1
# ContractRenewal
# 0                0.575851  0.424149
# 1                0.885050  0.114950

# %%
plt.figure()
df.boxplot(column='MonthlyCharge', by='Churn')
plt.title("Monthly Charge vs Churn")
plt.suptitle("")
plt.show()
#customers paying higher monthly bills are more likely to churn

# %%
plt.figure()
df.boxplot(column='OverageFee', by='Churn')
plt.title("Overage Fee vs Churn")
plt.suptitle("")
plt.show()
#here unexpected extra chargers fustrate the customers,morelikely the cuatomers churns

# %% [markdown]
# FEATURE ENGINNERING

# %%
df['ChargesPerMin'] = df['MonthlyCharge'] / (df['DayMins'] + 1)
df['HighServiceCalls'] = (df['CustServCalls'] >= 3).astype(int)
df['HighOverage'] = (df['OverageFee'] > df['OverageFee'].median()).astype(int)

df.head()
# Out:
#    Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  CustServCalls  \
# 0      0           128                1         1        2.7              1
# 1      0           107                1         1        3.7              1
# 2      0           137                1         0        0.0              0
# 3      0            84                0         0        0.0              2
# 4      0            75                0         0        0.0              3
#
#    DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins  ChargesPerMin  \
# 0    265.1       110           89.0        9.87      10.0       0.334461
# 1    161.6       123           82.0        9.78      13.7       0.504305
# 2    243.4       114           52.0        6.06      12.2       0.212766
# 3    299.4        71           57.0        3.10       6.6       0.189747
# 4    166.7       113           41.0        7.42      10.1       0.244484
#
#    HighServiceCalls  HighOverage
# 0                 0            0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Churn', axis=1)
y = df['Churn']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, stratify=y, random_state=42
)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipeline_lr = Pipeline([
    ('scaler', StandardScaler()),
    ('lr', LogisticRegression(class_weight='balanced', max_iter=1000))
])

# %%
pipeline_lr.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('lr',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix

# %%
y_pred = pipeline_lr.predict(X_test)
y_prob = pipeline_lr.predict_proba(X_test)[:,1]

# %%
print(classification_report(y_test, y_pred))
print("ROC-AUC:", roc_auc_score(y_test, y_prob))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84       713
#            1       0.34      0.73      0.47       121
#
#     accuracy                           0.76       834
#    macro avg       0.64      0.75      0.66       834
# weighted avg       0.86      0.76      0.79       834
#
# ROC-AUC: 0.8133367333928344
# Confusion Matrix:
#  [[545 168]
#  [ 33  88]]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(
    n_estimators=200,
    class_weight='balanced',
    random_state=42
)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200,
#                        random_state=42)

# %%
rf_pred = rf.predict(X_test)
rf_prob = rf.predict_proba(X_test)[:,1]

# %%
print(classification_report(y_test, rf_pred))
print("ROC-AUC:", roc_auc_score(y_test, rf_prob))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       713
#            1       0.84      0.64      0.72       121
#
#     accuracy                           0.93       834
#    macro avg       0.89      0.81      0.84       834
# weighted avg       0.93      0.93      0.93       834
#
# ROC-AUC: 0.8582812699222236

# %%
importances = pd.Series(rf.feature_importances_, index=X.columns)

# %%
importances.sort_values(ascending=False).head(10)
# Out:
# DayMins            0.161608
# MonthlyCharge      0.139046
# CustServCalls      0.134926
# ContractRenewal    0.097604
# ChargesPerMin      0.095639
# OverageFee         0.076222
# RoamMins           0.062418
# AccountWeeks       0.055906
# DayCalls           0.053138
# DataUsage          0.052180
# dtype: float64

# %% [raw]
# ## Key Business Insights
#
# - Customers with frequent customer service interactions have the highest churn risk
# - Contract renewal significantly reduces churn probability
# - High billing and overage charges strongly drive churn
# - Proactive intervention can reduce churn by targeting high-risk customers early

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10],
    'min_samples_leaf': [1, 2]
}

# %%
rf = RandomForestClassifier(
    class_weight='balanced',
    random_state=42
)

# %%
grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    scoring='recall',   # because churn detection matters
    cv=5,
    n_jobs=-1
)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [None, 10], 'min_samples_leaf': [1, 2],
#                          'n_estimators': [100, 200]},
#              scoring='recall')

# %%
grid_search.best_params_
# Out:
# {'max_depth': 10, 'min_samples_leaf': 2, 'n_estimators': 200}

# %%
best_rf = grid_search.best_estimator_

y_pred = best_rf.predict(X_test)
y_prob = best_rf.predict_proba(X_test)[:, 1]

# %%
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix

y_pred_tuned = best_rf.predict(X_test)
y_prob_tuned = best_rf.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred_tuned))
print("ROC-AUC:", roc_auc_score(y_test, y_prob_tuned))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_tuned))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       713
#            1       0.68      0.70      0.69       121
#
#     accuracy                           0.91       834
#    macro avg       0.81      0.82      0.82       834
# weighted avg       0.91      0.91      0.91       834
#
# ROC-AUC: 0.8723354931438574
# Confusion Matrix:
#  [[673  40]
#  [ 36  85]]

# %% [markdown]
# FEATURE IMPORTANCE

# %%
importances = pd.Series(
    best_rf.feature_importances_,
    index=X_train.columns
).sort_values(ascending=False)

# %%
importances
# Out:
# DayMins             0.172502
# CustServCalls       0.154386
# MonthlyCharge       0.141125
# ContractRenewal     0.115720
# ChargesPerMin       0.087143
# OverageFee          0.066520
# DataUsage           0.054163
# RoamMins            0.053661
# AccountWeeks        0.043435
# DayCalls            0.040844
# HighServiceCalls    0.037639
# DataPlan            0.022593
# HighOverage         0.010268
# dtype: float64

# %%
plt.figure()
importances.head(10).plot(kind='barh')
plt.xlabel("Importance Score")
plt.title("Top 10 Feature Importances - Random Forest")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# XGBOOST

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    scale_pos_weight = (y_train == 0).sum() / (y_train == 1).sum(),  # handle imbalance
    random_state=42
)

xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
from sklearn.metrics import classification_report, roc_auc_score

xgb_pred = xgb.predict(X_test)
xgb_prob = xgb.predict_proba(X_test)[:, 1]

print(classification_report(y_test, xgb_pred))
print("ROC-AUC:", roc_auc_score(y_test, xgb_prob))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95       713
#            1       0.70      0.65      0.68       121
#
#     accuracy                           0.91       834
#    macro avg       0.82      0.80      0.81       834
# weighted avg       0.91      0.91      0.91       834
#
# ROC-AUC: 0.8594693588955988

# %%
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [3, 5],
    'learning_rate': [0.05, 0.1],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0]
}

# %%
from sklearn.model_selection import GridSearchCV

xgb_base = XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    scale_pos_weight=(y_train == 0).sum() / (y_train == 1).sum(),
    random_state=42
)

grid_search_xgb = GridSearchCV(
    estimator=xgb_base,
    param_grid=param_grid,
    scoring='recall',
    cv=5,
    n_jobs=-1,
    verbose=1
)

grid_search_xgb.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False,
#                                      eval_metric='logloss', feature_types=None,
#                                      feature_weights=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraint...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
# ...

# %%
grid_search_xgb.best_params_
# Out:
# {'colsample_bytree': 0.8,
#  'learning_rate': 0.05,
#  'max_depth': 3,
#  'n_estimators': 100,
#  'subsample': 1.0}

# %%
best_xgb = grid_search_xgb.best_estimator_

# %%
xgb_tuned_pred = best_xgb.predict(X_test)
xgb_tuned_prob = best_xgb.predict_proba(X_test)[:, 1]

print(classification_report(y_test, xgb_tuned_pred))
print("ROC-AUC:", roc_auc_score(y_test, xgb_tuned_prob))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.87      0.91       713
#            1       0.51      0.80      0.62       121
#
#     accuracy                           0.86       834
#    macro avg       0.73      0.83      0.77       834
# weighted avg       0.90      0.86      0.87       834
#
# ROC-AUC: 0.8658328793481159

# %% [markdown]
# CUSTOMER SEGMENTATION AND RETENTION ANALYSIS

# %%
seg_features = [
    'DayMins',
    'MonthlyCharge',
    'CustServCalls',
    'DataUsage',
    'RoamMins',
    'ChargesPerMin',
    'AccountWeeks'
]

X_seg = df[seg_features]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_seg)

# %%
from sklearn.cluster import KMeans

inertia = []

for k in range(2, 8):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

plt.plot(range(2, 8), inertia, marker='o')
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal K")
plt.show()

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
df['Segment'] = kmeans.fit_predict(X_scaled)

# %%
segment_profile = df.groupby('Segment')[seg_features].mean()
segment_profile
# Out:
#             DayMins  MonthlyCharge  CustServCalls  DataUsage   RoamMins  \
# Segment
# 0        221.229435      56.749158       0.983152   0.130714   9.997820
# 1        131.613410      41.156513       1.188697   0.163640  10.060728
# 2        185.178323      78.895355       1.409032   2.952245  10.932129
# 3        189.342032      52.215339       3.737052   0.254602  10.028088
# 4          0.866667      27.266667       2.666667   0.926667   7.733333
#
#          ChargesPerMin  AccountWeeks
# Segment
# 0             0.258071     99.727453
# 1             0.335281    101.289272
# 2             0.449675    102.401290
# 3             0.283738    101.177291
# 4            15.759259    108.666667

# %%
df.groupby('Segment')['Churn'].mean()
# Out:
# Segment
# 0    0.210109
# 1    0.056513
# 2    0.073548
# 3    0.306773
# 4    0.333333
# Name: Churn, dtype: float64

# %%
df['Churn_Prob'] = best_xgb.predict_proba(X)[:, 1]

df.groupby('Segment')['Churn_Prob'].mean()
# Out:
# Segment
# 0    0.364812
# 1    0.178386
# 2    0.234630
# 3    0.494494
# 4    0.425263
# Name: Churn_Prob, dtype: float32
